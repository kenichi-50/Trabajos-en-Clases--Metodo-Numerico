# %% [markdown]
# # Quizz
# ## Nombre:
# Joel Stalin Tinitana Carrion
# ## Fecha:
# 05/05/2025

# %%
# Importar las bibliotecas necesarias
import numpy as np
import matplotlib.pyplot as plt

# Definir la función corregida
def f(x):
    return x**3 - 3*x**2 + x - 1  # Corregir la ecuación

# Recalcular y
y = f(x)

# Graficar la función corregida
plt.figure(figsize=(8, 5))
plt.plot(x, y, label=r'$f(x) = x^3 - 3x^2 + x - 1$', color='red')
plt.axhline(0, color='gray', linestyle='--')  # Eje X
plt.axvline(0, color='gray', linestyle='--')  # Eje Y

# Mejorar la visualización
plt.title('Gráfica de $f(x) = x^3 - 3x^2 + x - 1$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
def f(x):
    return x*3 - 3*x*2 + x - 1

def biseccion(a, b, tol=1e-6, max_iter=100):
    if f(a) * f(b) >= 0:
        print("El método de bisección no es aplicable en este intervalo.")
        return None

    iteraciones = 0
    while (b - a)/2 > tol and iteraciones < max_iter:
        c = (a + b)/2
        if f(c) == 0:
            break  # Se encontró la raíz exacta
        elif f(a) * f(c) < 0:
            b = c
        else:
            a = c
        iteraciones += 1

    c = (a + b)/2
    print(f"Raíz aproximada: {c:.6f} encontrada en {iteraciones} iteraciones.")
    return c

# Ejecutar el método en el intervalo [-1, 4]
biseccion(-1, 4)
# Out:
# Raíz aproximada: -0.500000 encontrada en 22 iteraciones.
# -0.49999988079071045

# %%
from scipy.optimize import newton

# Definir la derivada de la función
def f_prime(x):
    return 3*x**2 - 6*x + 1

# Usar el método de Newton con full_output=True
x0 = 100  # Valor inicial
# Definir la función f(x) que falta
def f(x):
    return x**3 - 3*x**2 + x - 1

# Usar el método de Newton con full_output=True
raiz, info = newton(f, x0, fprime=f_prime, full_output=True)

# Mostrar los resultados
print(f"La raíz encontrada usando el método de Newton con x0={x0} es: {raiz:.6f}")
print(info)
# Out:
# La raíz encontrada usando el método de Newton con x0=100 es: 2.769292
#       converged: True
#            flag: converged
#  function_calls: 30
#      iterations: 15
#            root: 2.7692923542386314
#          method: newton

# %%
from scipy.optimize import newton

# Definir la función con argumentos adicionales
def f(x, a=1, b=-3, c=1, d=-1):
    return a*x*3 + b*x*2 + c*x + d

# Definir la derivada de la función con los mismos argumentos
def f_prime(x, a=1, b=-3, c=1, d=-1):
    return 3*a*x**2 + 2*b*x + c

# Argumentos adicionales para la función
args = (1, -3, 1, -1)  # Coeficientes a, b, c, d

# Lista para almacenar los valores de f(x) en cada iteración
valores_fx = []

def f_with_output(x, *args):
    """Función que almacena los valores de f(x) en cada iteración."""
    valores_fx.append(f(x, *args))  # Guardar solo f(x)
    return f(x, *args)

# Usar el método de Newton con full_output=True y args
x0 = 100  # Valor inicial
raiz, info = newton(f_with_output, x0, fprime=f_prime, args=args, full_output=True)

# Mostrar los valores de f(x) en cada iteración
print("Valores de f(x) en cada iteración:")
for fx in valores_fx:
    print(f"{fx:.6f}")

# Mostrar la raíz final
print(f"\nLa raíz encontrada usando el método de Newton con x0={x0} es: {raiz:.6f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[30], line 24
#      22 # Usar el método de Newton con full_output=True y args
#      23 x0 = 100  # Valor inicial
# ---> 24 raiz, info = newton(f_with_output, x0, fprime=f_prime, args=args, full_output=True)
#      26 # Mostrar los valores de f(x) en cada iteración
#      27 print("Valores de f(x) en cada iteración:")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\scipy\optimize\_zeros_py.py:391, in newton(func, x0, fprime, args, tol, maxiter, fprime2, x1, rtol, full_output, disp)
#     388 if disp:
#     389     msg = ("Failed to converge after %d iterations, value is %s."
#     390            % (itr + 1, p))
# --> 391     raise RuntimeError(msg)
#     393 return _results_select(full_output, (p, funcalls, itr + 1, _ECONVERR), method)
#
# RuntimeError: Failed to converge after 50 iterations, value is 100.34124008432656.

# %%
# Evaluar la función en x = 100
x_eval = 0
resultado = f(x_eval)

print(f"El valor de f(100) es: {resultado}")
# Evaluar la derivada de la función en x = 100


resultado_derivada = f_prime(x_eval)

print(f"La derivada de f(x) en x = 100 es: {resultado_derivada}")
# Out:
# El valor de f(100) es: -1
# La derivada de f(x) en x = 100 es: 1
